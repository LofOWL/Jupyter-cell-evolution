# %%
from RepoNotebooks import RepoNotebook
from CollectMapping import mapping
from CollectNotebook import name
from Data import REPOS_PATH
from Config import SAVE_FOLDER
from subprocess import getoutput
import os

# %%
notebook_cache_path = SAVE_FOLDER + "/notebook_cache"

# %%
cache = os.listdir(notebook_cache_path)

# %%
def find(name):
    os.chdir(notebook_cache_path)
    result = getoutput(f'find -name {name}')
    return len(result) > 1

# %%
def check(rpn,cache):
    collect = list()
    all_commits = rpn.all_notebooks_commits()
    for commit in all_commits:
        notebooks = rpn.get_notebook_commit_details(commit)
        for type,notebook in notebooks:
            if type != "D":
                collect.append(find(name(commit,notebook)))
    return any(collect)

# %%
from tqdm import tqdm
log = list()
for repo in tqdm(REPOS_PATH[:3]):
    rp = RepoNotebook(repo)
    result = check(rp,cache)
    if not result:
        log.append(repo)
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# /media/lofowl/My Passport/1353_notebook_projects/frnsys#ai_notes/ai_notes
# Previous HEAD position was 376b094 clean up
# Switched to branch 'master'
# rm: cannot remove '/media/lofowl/My Passport/1353_notebook_projects/frnsys#ai_notes/ai_notes/.git/index.lock': No such file or directory
#  33%|███▎      | 1/3 [00:01<00:02,  1.32s/it]Already on 'master'
# rm: cannot remove '/media/lofowl/My Passport/1353_notebook_projects/matsuken92#Qiita_Contents/Qiita_Contents/.git/index.lock': No such file or directory
# Your branch is up to date with 'origin/master'.
# /media/lofowl/My Passport/1353_notebook_projects/frnsys#ai_notes/ai_notes
# init success
# 6b54550e7861677ad4410db245523331952f4c74
# [['M', 'graphics/pgms.ipynb']]
# M graphics/pgms.ipynb
# ea960ae741d9b2c9dae9a54e8d0fa44a3f16d5da
# []
# 7e732bfad6ca09d1e75a3ba960ccd2b812ccd265
# []
# 87d848d425ed907e85b194b5c0f896e4a153bee9
# []
# ac60e19a29d7fddd38418441f110d1437a7cb0e4
# []
# 759f9bb740cfbb272f1b35dfc78f918f89b68674
# []
# 5d3bd8305653daca3ece76a60d3162bf70da0bb2
# []
# 8336e016614e784c0ca8820574798ab3e8606732
# []
# 376b094aa6a3f4572774e15e7659af9eb82981b3
# []
# b4e73149ebfe990fabc4eb927250f3ea8ee4649c
# []
# 28243a68800ef8f41e92d3d43296787940b97aac
# []
# /media/lofowl/My Passport/1353_notebook_projects/matsuken92#Qiita_Contents/Qiita_Contents
# Your branch is up to date with 'origin/master'.
# /media/lofowl/My Passport/1353_notebook_projects/matsuken92#Qiita_Contents/Qiita_Contents
# init success
# 81e236ab376712f1a0e80fcb4d0d437e0c6bf64d
# [['M', 'plotly_demo/plotly_demo.ipynb']]
# M plotly_demo/plotly_demo.ipynb
# d40c7a3ca4018ea46fc5a4d3ba939a463c469390
# []
# ef0c934e8a92eade01595dff685957620f0c1036
# []
# 6242dd265522a2a244aabb369b08ab660ef1cf4e
# []
# 6d115e45fc15fede77ceed784a5a5156127542ce
# []
# 3734486c78d19b3ef19e493f4c7e7b1beb98b02e
# []
# c9a0a4f070b55b19cf3c5b280909078fc0b0be60
# []
# f030cb6608dc2aed8b4d7166e8bddc28f2af214a
# []
# 24efa557bdd4ae001d6e8b9779d2f6d2dc27d9b5
# []
# ddd338fcac80af4641be4b32cdecac0a1e3d5964
# []
# 12adf41284803df69826abdf776b6eb4d769ab27
# []
# 172f3ca4c0755c3994a5438a65a1bd51697a23c9
# []
# []
# 86b7cf13bd22d2b078aaf12f18036da3f0bb20a1
# []
# 249db95dcd5e7c858b89f06d4678f5a5b4f6ed4b
# []
# 67733278af005734b23212cef3a7868889d7d765
# []
# d7dcb58070a84e84b9e6e08c1bf30abc5dcf5369
# []
# 9c5de3b9aa4192823a416fad95e7fe64531f5d68
# []
# 77151a199bb840d899ddc4d058cb353a29f59d16
# []
# 87abd89a7963005e1352fad1afae978adc27a164
# []
# a95a22e1fe86fa56d2d2250e1280a2463c6cb0af
# []
# 62de349aa59677b67ab90ed8ffa30780aa5a06fe
# []
# ce8b0ccef8a46571e3edb0daa7251a554e065876
# []
# 5194bdbecc447f594f5d77263bd8908fcf0ed030
# []
# 71cbf034268a4428997f29d7102c10f060202ec7
# []
# adfaaf1afe62fb4f6ca639d2f0b6bfb62ba0b7c6
# []
# 38428f287eb20bebf205b3f647bd92145dc533f6
# []
# acfd049b4fb2b079d7cf9e982f9d88f9a54c2b62
# []
# 8ce4c00be3bd093c923514b1a5b459970e7eae8a
# []
# 0a7de2a36b3c447efaeaebb985ff65cb554f4de7
# []
# b978cd9ca6b492f7a20edaac83c73654160a5822
# []
# 51a6c99cc14a0236ff64c6bc4290093db594ab35
# []
# 404fc8d1de42b96d6aebe2482820170ea34a6539
# []
# f8045ed5260991b69825c76489ae13c29984391f
# []
# eead76a9c34a48247961c81c7c656aa8d4f194e0
# []
# 2d4731129b7a4989ca4ef3a6ef425633704f1208
# []
# 1ede1761160d1c030f3a9cd7a76ff429a9dd4d11
# []
# 1d9ffa307cb96a55e69a5572aa0f2327e6aadefb
# []
# d574d7b1d21c9fe0d3ba389074def0cba36d3fde
# []
# 579d0a42cf365d32a57a4426bcafdaac1b525e63
# []
# d92aa708ce84040d1030141d09f0bb9afea1e33e
# []
# 530ca043937df5b26f298230782209ad0993f487
# []
# bdb01099703d79d44d804466b85ef12b829c5b7a
# []
# b2c9dede11e0364e9335b5e3392a26daaa96530e
# []
# 42ee10f3e489a783240abd713e9816c3f5e33343
# []
# b7b31319b644ebf302e8efde9ecac7ad7467c444
# []
# 830f4937fb3545eaafcd7e5ea8058ae9291eeac1
# []
# 727fefcc2438d0ce4dd8bea3ea0fc01c95bba54f
# []
# 18b8b09b283245b9e63cbdfb1a36e1fc17dd5b19
# []
# fef1e1487262e26f68a8c36ec6b391ecc9bf36cf
# []
# e655c31296e65e2b0819f7bbd7aeefd02f690481
# []
# 26e2cb3b1a96150c54c0196826887b68c0bd9933
# []
# 53fd99158bc7d331112055795087b82d8fd5a06e
# []
# 2f51ddd03b462738e7ab829921c1e55e0c2febb8
# []
# 5c7ca032fe042bc86d5fcd343f72490b282170eb
# []
# 7fb695620cb6ad633e0faeb6567db91580eec5f6
# []
# 7404573ee9e51ddaeb9229bfeb321b34dc282ca2
# []
# 3846d9ca3cd63a2aa6b18ce37b5e57f0fef71a89
# []
# 52ff519001a91e3790ff2a796be7c9feb29a5c40
# []
# 6ce4e5137335db6e723d9a62a0e7ba31b983c93f
# []
# 556b7c268d3b59a8bd60a6143f7ff8d0b7f1d5d4
# []
# ef0e6fa31a8130a5ffca2e833d490cf31e44c1a8
# []
# 80a1aaa71495cee68383908fbaac8f0ef01dbfd2
# []
# 70b141ca372f368a47d9f0bf1356eb4b65c81eec
# []
# 45640f13f37370cea56947646b24154a6ba124df
# []
# d467d15961a8fd148232643c595c5915e57bef0c
# []
# 3788485c9bb90fcc393d5a50d9c62a991aa7f246
# []
# 8e31b9661684f242670bed76ff4fc4645cc5610a
# []
# d800cabf466ce34c89aa6898081b0c15f5b51635
# []
# abd2a877b117814f30d1f4a90849f63532d2f182
# []
# 9d2370c2964746f303532929986703396125e824
# []
# 2bbaf3685981000c87325fa0995f4fdaa346019d
# []
# e7b74e3d01c5b3840f3102bbebc5d0e1fdc313a2
# []
# 8faeb3fe5d4761fd0187ab64464b3ae30b6f05ba
# []
# 38179c0e9626561b47b7a2720e0e423eaad77413
# []
# 20aa7979d09089eee8f6fd307b751770fcdc0e48
# []
# 8fb916bd1e23b98fa666d7ff297069173e9a4f4e
# []
# c60f045b5f86abb7908c8d4b13bc26b2a9795031
# []
# f8364ac2e23b64bdfd45b3a5b6a75e4837e6ecb7
# []
# 49756200864d6f7ea24c22242fb7da700b30d5be
# []
# 3d0aa5ac7cf16113883243f79c68f952780c0c5e
# []
# d0bfd1adce0a97cbc068ad33a05bb64fdd47ab07
# []
# 2c9bc4966ce0106e76d3a2b86198e5de595c79db
# []
# 0ef71a9d8f78f967d736c13695856a2089036a20
# []
#  67%|██████▋   | 2/3 [00:02<00:01,  1.27s/it]
# 01e8db8059670a793e7bb53a98bf76aaa2e53698
# []
# a41d8895178b7518ad86f35faab1180e23709f6c
# []
# e2eeda65e0338e03473d2ae3614699898e1bf37a
# []
# 5a62065c56cb3bf650f064af54fd29baeea99558
# []
# 4544021ce7ff14403362c9800070962aae4a8234
# []
# ab5e3a307f9aa80dba02d0482a10aed0b73348a1
# []
# 592de4b6319712e0f8a89e763a9d9e4bc55cc6af
# []
# 74ca9c4b9d2f373b31afb9f18b8e20adc577da3d
# []
# 428a9477feb76d76f373643d0a51b1a72541d4e9
# []
# 2ebcf31099820a1fad04234ca8486fa4170539e1
# []
# 32b4006305b4ef88c803d2c1dae524aaccae3df8
# []
# /media/lofowl/My Passport/1353_notebook_projects/18F#tech-talks/tech-talks
# Your branch is up to date with 'origin/master'.
# /media/lofowl/My Passport/1353_notebook_projects/18F#tech-talks/tech-talks
# init success
# 68b03ade498508730b4c20ca0011c70ac8cb1d75
# [['A', 'etl/etl-lessons-learned.ipynb']]
# A etl/etl-lessons-learned.ipynb
# Already on 'master'
# rm: cannot remove '/media/lofowl/My Passport/1353_notebook_projects/18F#tech-talks/tech-talks/.git/index.lock': No such file or directory
# 100%|██████████| 3/3 [00:02<00:00,  1.10it/s]
# 5dbb517f89c3267e7358224a248b7229bf70bf52
# []
# c2bedd3921fecd401ebf1c7b126d85a92fa2e17a
# []
# 495ab7ed59deb2b87f49e5cb3da3b0a7f5c8ccc7
# []
# 42ac21ec3dde322027303eb517b5f389b9d56826
# []
# 92c4b40e97855fc0f63071c04b3af0e0d77dc592
# []
# d72d84f3e7fb0a9bd7c10a39346818c2a1623e94
# []
# 7d6e5f0bd9197928538328dafeea830e1678e8b7
# []
# f886489d5ea631f05cbd8fb35c445e75e51c0b36
# []
# 824437d3363aa40a9cf7cbd0b1bf5e607236253e
# []
# d7641c604dd71394a60cce912e41ad6461d70e19
# []
# c7c429e716a784f800c5d16e64dafd40595c39ec
# []
